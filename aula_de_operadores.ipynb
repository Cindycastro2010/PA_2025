# %% [markdown]
# <a href="https://colab.research.google.com/github/Cindycastro2010/PA_2025/blob/main/aula_de_operadores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Adição

# %%
3+5
# Out:
# 8

# %% [markdown]
# #Subtração

# %%
9-4
# Out:
# 5

# %% [markdown]
# #Multiplicação

# %%
5*6
# Out:
# 30

# %% [markdown]
# #Divisão

# %%
4/5
# Out:
# 0.8

# %% [markdown]
# #Igualdade

# %%
a = 4
a==4
# Out:
# True

# %%
a = 4
a==3
# Out:
# False

# %%
#Expoente

# %%
4**3
# Out:
# 64

# %% [markdown]
# #Maior, menor, maior ou igual e menor ou igual

# %%
5>2
# Out:
# True

# %%
5>6
# Out:
# False

# %%
5>=6
# Out:
# False

# %%
5-6+8+15*(6/2)+4-9
# Out:
# 47.0

# %% [markdown]
# #Diferente

# %%
a!=4
# Out:
# False

# %% [markdown]
# #Variaveis

# %%
nome = "Cindy"
sobrenome = "Castro"

print ("meu nome é" + " "+ nome + " " + " " +sobrenome)
# Out:
# meu nome é Cindy  Castro

# %%
from re import
# Out:
#   File "<ipython-input-22-dd1ae2813b69>", line 1
#     from re import
#                    ^
# SyntaxError: invalid syntax

# %%
nome1= str(input("Digite seu nome: "))
sobrenome = str(input("Digite seu sobrenome: "))

print ("meu nome é" + " "+ nome + " " + " " +sobrenome)
# Out:
# Digite seu nome: Cindy
# Digite seu sobrenome: Castro
# meu nome é Cindy  Castro

# %%
print (nome)
# Out:
# Cindy

# %%
#entrada
lado = int(input(" digite o lado do quadrado: "))

#processamento
area = lado*lado

#saida
print ("a area do quadrado é igual a", area)
# Out:
#  digite o lado do quadrado: 6
# a area do quadrado é igual a 36

# %%
#entrada
lado = float(input(" digite o lado do quadrado: "))

#processamento
area = lado*lado

#saida
print ("a area do quadrado é igual a", area)
# Out:
#  digite o lado do quadrado: 4.5
# a area do quadrado é igual a 20.25
