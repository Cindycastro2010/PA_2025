# %% [markdown]
# <a href="https://colab.research.google.com/github/Cindycastro2010/PA_2025/blob/main/07_03_25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#entrada
not = float(input("digite a primeira nota"))

#processamento
media = (nota1 + nota2) / 2

#saida
print(" a media é:", media)

a1 = float(input("digite a primeira nota:"))
nota2

# %%
#entrada
numero = float(input('digite o numero'))
#processamento
rusultado = numero % 2
#saida
print('o resultado é', resultado )

# %%
#entrada
e=float(input('digite a temperatura em celcius '))
f = e*1.8+32
print('a temperatura em fahrenheit é', f)
# Out:
# digite a temperatura em celcius 10
# a temperatura em fahrenheit é 50.0

# %%
#entrada
e=float(input('digite a distância percorridas em milhas'))
f = e*1.60934
print('a distância em quilômetros', f)
# Out:
# digite a distância percorridas em milhas8
# a distância em quilômetros 12.87472
