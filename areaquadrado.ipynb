# %% [markdown]
# <a href="https://colab.research.google.com/github/Cindycastro2010/PA_2025/blob/main/areaquadrado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
aula = "hello world"

# %%
print (aula)
# Out:
# hello world

# %%
#Entrada
lado = 4

# %%
#processamento
area = lado * lado

# %%
#saida
print("A área do quadrado é", area)
# Out:
# A área do quadrado é 16
